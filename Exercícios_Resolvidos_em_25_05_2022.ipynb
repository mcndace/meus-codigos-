# %% [markdown]
# <a href="https://colab.research.google.com/github/mcndace/meus-codigos-/blob/main/Exerc%C3%ADcios_Resolvidos_em_25_05_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="data:image/png;base64,...">

# %%
## Entrada de Dados com Tratamento de Erro:
while True:
    n = int( input("\n\tDigite um numero positivo >= 2: "))
    if ( n < 2 ):
        print("\n\tNúmero Inválido... Digite novamente...\n")
    else:
        break
while True:
    lim_inf = int( input("\n\tDigite o limite inferior: "))
    lim_sup = int( input("\n\tDigite o limite superior >= do que o inferior: "))
    if ( lim_inf <= 0) or ( lim_sup <= 0) or (lim_sup < lim_inf ):
        print("\n\tLimites Inválidos... Digite novamente...\n")
    else:
        break
## Processamento e saída de dados
print(f"\n\n\tNúmeros Múltiplos de {n} no intervalo [ {lim_inf}, {lim_sup}]:\n")
print(end="\t" )
for i in range( lim_inf, lim_sup+1):
    if ( i % n == 0 ):
        print(i, end=' ')
# Out:
# 	Digite um numero positivo >= 2: 2
#
# 	Digite o limite inferior: 1
#
# 	Digite o limite superior >= do que o inferior: 8
#
#
# 	Números Múltiplos de 2 no intervalo [ 1, 8]:
#
# 	2 4 6 8

# %% [markdown]
# <img src="data:image/png;base64,...">

# %%
#Inicialização das Variáveis
tot_hab = 5
conta_emp = 0
conta_desemp = 0

# Entrada de Dados com tratamento de erro + Processamento de Ddados
for hab in range(tot_hab):
    while True:
        resp = int ( input(f"\n\tHabitante {hab+1} digite [1] para empregado ou [0] para Desempregado: "))
        if ( resp < 0) or ( resp > 1 ):
            print("\n\tOpção Inválida!\n")
        else:
            break
    if ( resp == 1):
        print(f"\n\tO habitante {hab+1} afirmou estar empregado!")
        conta_emp += 1
    else:
        print(f"\n\tO habitante {hab+1} afirmou estar desempregado!")
        conta_desemp += 1
    
# Saída de Dados
print(f"\n\tPorcentagem Final: Empregados={conta_emp/tot_hab * 100}%     Desempregados={conta_desemp/tot_hab * 100}%")
# Out:
# 	Habitante 1 digite [1] para empregado ou [0] para Desempregado: 1
#
# 	Habitante 2 digite [1] para empregado ou [0] para Desempregado: 0
#
# 	Habitante 3 digite [1] para empregado ou [0] para Desempregado: 0
#
# 	Habitante 4 digite [1] para empregado ou [0] para Desempregado: 0
#
# 	Habitante 5 digite [1] para empregado ou [0] para Desempregado: 0
#
# 	Porcentagem Final: Empregados=20.0%     Desempregados=80.0%
